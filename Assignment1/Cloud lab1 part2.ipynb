# %%
# Reading File
def readFile(filename):
    contents = filename.read()
    return contents;


# Printing top ten words of sorted dict
def printDictTen(dict1):
    for i in range(10):
        print(str(dict1[i][0]) + " : " + str(dict1[i][1]))
    
    
# Checking if dictionary contains the searched key
def checkKey(dict1, word): 
      
    if word in dict1.keys(): 
        return 1
    else: 
        return 0

    
# Counting the number of words in the file and also returning the dictionary that contains the word count of the file
def wordCount(contents):
    dict1 = {}
    count = 0
    for word in contents.split():
#         print(type(word))
        if checkKey(dict1, word) == 1:
            dict1[word] += 1
            count += 1
        else:
            dict1[word] = 1
            count += 1
    print("Number of words in the file are:" ,count,"\n")
    return dict1
     

# it gives the top ten word in the dictionary by sorting the dictionary in decreasing order
def topTenWords(wordCountDict):
    wordCountDict = sorted(wordCountDict.items(), key=lambda x: x[1], reverse=True)
    print("Top 10 words are:")
    printDictTen(wordCountDict)

        

        
# ignoring stop words listed in the list and then giving top ten words in the file
def stopWords(dict1):
    list1 = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", 
             "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", 
             "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", 
             "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and", 
             "but", "if", "or", "because", "as", "until", "while", "of", "at","by", "for", "with", "about", "against", "between", "into", "through", 
             "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", 
             "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", 
             "most", "other", "some", "such", "no", "nor", "not", "only", 
             "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]
    stop = 0
    for i in range(len(list1)):
        if checkKey(dict1, list1[i]) == 1:
            del dict1[list1[i]]
            
    dict1 = sorted(dict1.items(), key=lambda x: x[1], reverse=True)
    print("Top 10 words after ignoring stop Words are:")
    printDictTen(dict1)

        
# It is the main function that calls all other fucntion    
def main():
    filename= open('C:/Users/HP/Desktop/sem 5/cloud lab/Assignment1/sample.txt', 'r')
    contents= readFile(filename)
    print("*******Question 2(Part 1)*******\n")
    wordCountDict= wordCount(contents)
    topTenWords(wordCountDict)
    print("\n*******Question 2(Part 2)*******\n")
    stopWords(wordCountDict)
    filename.close()
    

# it calls the main function
if __name__ == "__main__": 
    main()
# Out:
# *******Question 2(Part 1)*******
#
# Number of words in the file are: 454
#
# Top 10 words are:
# the : 30
# and : 15
# a : 13
# is : 12
# of : 12
# in : 12
# will : 10
# to : 9
# he : 6
# are : 6
#
# *******Question 2(Part 2)*******
#
# Top 10 words after ignoring stop Words are:
# files : 5
# Languages : 5
# There : 4
# special : 4
# Turing : 4
# square : 4
# symbol : 4
# machine : 4
# future : 3
# document : 3
